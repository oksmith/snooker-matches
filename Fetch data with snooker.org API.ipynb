# %% [markdown]
# # Fetch Snooker match data
# [http://api.snooker.org/](http://api.snooker.org/)

# %%
import requests
import json

import pandas as pd

pd.options.display.max_columns = 500

# %%
def fetch_players(year_start, year_end):
    players_json = []
    for year in range(year_start, year_end+1, 1):
        players_json = players_json + requests.get('http://api.snooker.org/?t=10&st=p&s={}'.format(str(year))).json()
    return pd.DataFrame(players_json).drop_duplicates('ID')

def fetch_data(year_start, year_end, player_data=None):
    matches_json = []
    
    if player_data is None:
        player_data = fetch_players(year_start, year_end)
        
    for year in range(year_start, year_end+1, 1):
        for player_id in player_data['ID'].unique():
            try:
                matches_json = matches_json + requests.get('http://api.snooker.org/?t=8&p={}&s={}'.format(str(player_id), str(year))).json()
            except:
                continue
                
    return pd.DataFrame(matches_json).drop_duplicates()

def fetch_season_rankings(year_start, year_end):
    ranking_json = []
    for year in range(year_start-1, year_end, 1):  # season before the current event is what is required
        try:
            ranking_json = ranking_json + requests.get('http://api.snooker.org/?rt=MoneyRankings&s={}'.format(year)).json()
        except:
            continue
    
    return pd.DataFrame(ranking_json).drop_duplicates()


def fetch_events_data(year_start, year_end):
    events_json = []
    for year in range(year_start, year_end+1, 1):
        try:
            events_json = events_json + requests.get('http://api.snooker.org/?t=5&s={}'.format(year)).json()
        except:
            continue
    
    return pd.DataFrame(events_json).drop_duplicates()


def fetch_seedings_data(matches_data):
    seedings_json = []
    for event_id in matches['EventID'].unique():
        try:
            seedings_json = seedings_json + requests.get('http://api.snooker.org/?t=13&e={}'.format(event_id)).json()
        except:
            continue
    
    return pd.DataFrame(seedings_json).drop_duplicates()

# %%
players = fetch_players(2017, 2019)

# %%
players.columns
# Out:
# Index(['ID', 'Type', 'FirstName', 'MiddleName', 'LastName', 'TeamName',
#        'TeamNumber', 'TeamSeason', 'ShortName', 'Nationality', 'Sex',
#        'BioPage', 'Born', 'Twitter', 'SurnameFirst', 'License', 'Club', 'URL',
#        'Photo', 'PhotoSource', 'FirstSeasonAsPro', 'LastSeasonAsPro', 'Info'],
#       dtype='object')

# %%
players.head()
# Out:
#    ID  Type FirstName MiddleName    LastName TeamName  TeamNumber  TeamSeason  \
# 0   1     1      Mark          J    Williams                    0           0
# 1   2     1   Stephen                Maguire                    0           0
# 2   4     1     Marco                     Fu                    0           0
# 3   5     1    Ronnie             O'Sullivan                    0           0
# 4   8     1       Tom                   Ford                    0           0
#
#       ShortName Nationality Sex                                      BioPage  \
# 0  M J Williams       Wales   M   http://snooker.org/plr/bio/mwilliams.shtml
# 1                  Scotland   M
# 2                 Hong Kong   M
# 3  R O'Sullivan     England   M  http://snooker.org/plr/bio/rosullivan.shtml
# 4                   England   M
#
#          Born     Twitter  SurnameFirst License Club URL  \
# 0  1975-03-21  markwil147         False
# 1  1981-03-13                     False
# 2  1978-01-08   Marcofu18         False
# 3  1975-12-05  ronnieo147         False
# 4  1983-08-17  tomford147         False
#
#                                              Photo PhotoSource  \
# 0  http://snooker.org/img/players/MarkWilliams.png
# 1       http://snooker.org/img/players/Maguire.png
# 2           http://snooker.org/img/players/mfu.jpg
# 3    http://snooker.org/img/players/rosullivan.jpg
# 4       http://snooker.org/img/players/TomFord.png
#
#    FirstSeasonAsPro  LastSeasonAsPro Info
# 0              1992                0
# 1              1998                0
# 2              1998                0
# 3              1992                0
# 4              2001                0

# %%
players['ID'].value_counts().value_counts()
# Out:
# 1    163
# Name: ID, dtype: int64

# %% [markdown]
# Test

# %%
t = requests.get('http://api.snooker.org/?t=5&s=2015').json()
t

# %%
# %%time
matches = fetch_data(2017, 2019, test)
# Out:
# CPU times: user 1.77 s, sys: 141 ms, total: 1.91 s
# Wall time: 20min 38s

# %%
matches.columns
# Out:
# Index(['ID', 'EventID', 'Round', 'Number', 'Player1ID', 'Score1', 'Walkover1',
#        'Player2ID', 'Score2', 'Walkover2', 'WinnerID', 'Unfinished', 'OnBreak',
#        'WorldSnookerID', 'LiveUrl', 'DetailsUrl', 'PointsDropped',
#        'ShowCommonNote', 'Estimated', 'Type', 'TableNo', 'VideoURL',
#        'InitDate', 'ModDate', 'StartDate', 'EndDate', 'ScheduledDate',
#        'FrameScores', 'Sessions', 'Note', 'ExtendedNote'],
#       dtype='object')

# %%
matches.shape
# Out:
# (16266, 31)

# %%
matches.head()
# Out:
#         ID  EventID  Round  Number  Player1ID  Score1  Walkover1  Player2ID  \
# 0  3759470      621      1      61          1       0       True        184
# 1  4219494      622      1      60          1       5      False         90
# 2  3760426      620      7      31          1       4      False         42
# 3  3759791      620      8      16          1       4      False        101
# 4  3759799      620      9       8         96       2      False          1
#
#    Score2  Walkover2  WinnerID  Unfinished  OnBreak  WorldSnookerID LiveUrl  \
# 0       0      False         1       False    False          453170
# 1       3      False         1       False    False          453105
# 2       1      False         1       False    False          453311
# 3       1      False         1       False    False          506813
# 4       4      False         1       False    False          506818
#
#                                           DetailsUrl  PointsDropped  \
# 0  http://cuetracker.net/Tournaments/riga-masters...          False
# 1  http://cuetracker.net/Tournaments/china-champi...          False
# 2  http://cuetracker.net/Tournaments/riga-masters...          False
# 3  http://cuetracker.net/Tournaments/riga-masters...          False
# 4  http://cuetracker.net/Tournaments/riga-masters...          False
#
#    ShowCommonNote  Estimated  Type  TableNo  \
# 0           False      False     1        0
# 1            True      False     1        0
# 2            True       True     1        0
# 3            True       True     1        0
# 4           False       True     1        0
#
#                                       VideoURL              InitDate  \
# 0                                               2017-05-12T17:50:23Z
# 1  https://www.youtube.com/watch?v=jNtP5eMacos  2017-05-12T21:07:27Z
# 2                 https://youtu.be/8EK-3PydURY  2017-05-12T21:14:35Z
# 3  https://www.youtube.com/watch?v=3uRQRBKIAaQ  2017-05-12T21:16:41Z
# 4                                               2017-05-12T21:18:00Z
#
#                 ModDate             StartDate               EndDate  \
# 0  2017-05-31T15:07:42Z  2017-05-31T15:07:42Z  2017-05-31T15:07:42Z
# 1  2017-06-03T13:37:44Z  2017-06-03T13:37:44Z  2017-06-03T17:22:56Z
# 2  2017-06-23T16:08:16Z  2017-06-23T16:08:16Z  2017-06-23T18:10:23Z
# 3  2017-06-25T21:10:53Z  2017-06-24T13:02:31Z  2017-06-24T14:32:50Z
# 4  2017-06-24T16:24:22Z  2017-06-24T16:24:22Z  2017-06-24T17:52:23Z
#
#           ScheduledDate FrameScores Sessions Note ExtendedNote
# 0  2017-06-02T15:00:00Z
# 1  2017-06-03T13:30:00Z
# 2  2017-06-23T16:00:00Z
# 3  2017-06-24T12:00:00Z
# 4  2017-06-24T16:00:00Z

# %%
matches['WIN'] = (matches['WinnerID'] == matches['Player1ID']).astype(int)

# %%
matches.to_csv('Matches_data.csv', index=False)

# %%
matches = pd.read_csv('Matches_data.csv')

# %% [markdown]
# ## Append other data sources

# %%
(~matches[['Walkover1', 'Walkover2']].any(axis=1)).value_counts()
# Out:
# True     8728
# False     246
# dtype: int64

# %%
matches = matches.loc[~matches[['Walkover1', 'Walkover2']].any(axis=1)]

# %%
matches.head()
# Out:
#         ID  EventID  Round  Number  Player1ID  Score1  Walkover1  Player2ID  \
# 1  4219494      622      1      60          1       5      False         90
# 2  3760426      620      7      31          1       4      False         42
# 3  3759791      620      8      16          1       4      False        101
# 4  3759799      620      9       8         96       2      False          1
# 5  3759803      620     13       4         48       1      False          1
#
#    Score2  Walkover2  WinnerID  Unfinished  OnBreak  WorldSnookerID LiveUrl  \
# 1       3      False         1       False    False          453105     NaN
# 2       1      False         1       False    False          453311     NaN
# 3       1      False         1       False    False          506813     NaN
# 4       4      False         1       False    False          506818     NaN
# 5       4      False         1       False    False          506823     NaN
#
#                                           DetailsUrl  PointsDropped  \
# 1  http://cuetracker.net/Tournaments/china-champi...          False
# 2  http://cuetracker.net/Tournaments/riga-masters...          False
# 3  http://cuetracker.net/Tournaments/riga-masters...          False
# 4  http://cuetracker.net/Tournaments/riga-masters...          False
# 5  http://cuetracker.net/Tournaments/riga-masters...          False
#
#    ShowCommonNote  Estimated  Type  TableNo  \
# 1            True      False     1        0
# 2            True       True     1        0
# 3            True       True     1        0
# 4           False       True     1        0
# 5            True       True     1        0
#
#                                       VideoURL              InitDate  \
# 1  https://www.youtube.com/watch?v=jNtP5eMacos  2017-05-12T21:07:27Z
# 2                 https://youtu.be/8EK-3PydURY  2017-05-12T21:14:35Z
# 3  https://www.youtube.com/watch?v=3uRQRBKIAaQ  2017-05-12T21:16:41Z
# 4                                          NaN  2017-05-12T21:18:00Z
# 5  https://www.youtube.com/watch?v=bzPeIGRYroI  2017-05-12T21:18:27Z
#
#                 ModDate             StartDate               EndDate  \
# 1  2017-06-03T13:37:44Z  2017-06-03T13:37:44Z  2017-06-03T17:22:56Z
# 2  2017-06-23T16:08:16Z  2017-06-23T16:08:16Z  2017-06-23T18:10:23Z
# 3  2017-06-25T21:10:53Z  2017-06-24T13:02:31Z  2017-06-24T14:32:50Z
# 4  2017-06-24T16:24:22Z  2017-06-24T16:24:22Z  2017-06-24T17:52:23Z
# 5  2017-06-25T11:04:12Z  2017-06-25T11:04:12Z  2017-06-25T12:43:26Z
#
#           ScheduledDate FrameScores Sessions Note ExtendedNote  WIN
# 1  2017-06-03T13:30:00Z         NaN      NaN  NaN          NaN    1
# 2  2017-06-23T16:00:00Z         NaN      NaN  NaN          NaN    1
# 3  2017-06-24T12:00:00Z         NaN      NaN  NaN          NaN    1
# 4  2017-06-24T16:00:00Z         NaN      NaN  NaN          NaN    0
# 5  2017-06-25T09:00:00Z         NaN      NaN  NaN          NaN    0

# %%
events = fetch_events_data(2017, 2019)
seedings = fetch_seedings_data(matches)
rankings = fetch_season_rankings(2017, 2019)

# %%
players.to_csv('Players_data.csv', index=False)
events.to_csv('Events_data.csv', index=False)
seedings.to_csv('Seedings_data.csv', index=False)
rankings.to_csv('Rankings_data.csv', index=False)

# %%
players = pd.read_csv('Players_data.csv')
events = pd.read_csv('Events_data.csv')
seedings = pd.read_csv('Seedings_data.csv')
rankings = pd.read_csv('Rankings_data.csv')

# %%
matches = matches.merge(events.rename(columns={'ID': 'EventID'}), on='EventID', how='left', suffixes=('', '_event'))

# %%
matches = matches.merge(
    seedings.rename(columns={'Seeding': 'Player1Seeding', 'PlayerID': 'Player1ID'}), 
    on=['EventID', 'Player1ID'], 
    how='left'
)
matches = matches.merge(
    seedings.rename(columns={'Seeding': 'Player2Seeding', 'PlayerID': 'Player2ID'}), 
    on=['EventID', 'Player2ID'], 
    how='left'
)

# %%
matches = matches.merge(
    players[['ID', 'FirstSeasonAsPro']].rename(columns={'ID': 'Player1ID', 'FirstSeasonAsPro': 'Player1FirstSeasonAsPro'}), 
    on='Player1ID', 
    how='left'
)
matches = matches.merge(
    players[['ID', 'FirstSeasonAsPro']].rename(columns={'ID': 'Player2ID', 'FirstSeasonAsPro': 'Player2FirstSeasonAsPro'}), 
    on='Player2ID', 
    how='left'
)
matches['Player1YearsAsPro'] = matches['Season'] - matches['Player1FirstSeasonAsPro']
matches['Player2YearsAsPro'] = matches['Season'] - matches['Player2FirstSeasonAsPro']

# %%
matches['LastSeason'] = matches['Season'] - 1

# %%
matches = matches.merge(
    rankings[['PlayerID', 'Position', 'Season', 'Sum']].rename(columns={
        'PlayerID': 'Player1ID', 'Position': 'Player1LastSeasonRank', 'Season': 'LastSeason', 'Sum': 'Player1LastSeasonSum'
    }),
    on=['Player1ID', 'LastSeason'],
    how='left'
)
matches = matches.merge(
    rankings[['PlayerID', 'Position', 'Season', 'Sum']].rename(columns={
        'PlayerID': 'Player2ID', 'Position': 'Player2LastSeasonRank', 'Season': 'LastSeason', 'Sum': 'Player2LastSeasonSum'
    }),
    on=['Player2ID', 'LastSeason'],
    how='left'
)

# %%
matches.head(10)
# Out:
#         ID  EventID  Round  Number  Player1ID  Score1  Walkover1  Player2ID  \
# 0  4219494      622      1      60          1       5      False         90
# 1  3760426      620      7      31          1       4      False         42
# 2  3759791      620      8      16          1       4      False        101
# 3  3759799      620      9       8         96       2      False          1
# 4  3759803      620     13       4         48       1      False          1
# 5  3759842      620     14       2         68       5      False          1
# 6  3910645      635      1      37          1       5      False        416
# 7  3851063      623      7      30        218       2      False          1
# 8  3853804      623      8      15         68       0      False          1
# 9  3889522      623      9       8          1       5      False          8
#
#    Score2  Walkover2  WinnerID  Unfinished  OnBreak  WorldSnookerID LiveUrl  \
# 0       3      False         1       False    False          453105     NaN
# 1       1      False         1       False    False          453311     NaN
# 2       1      False         1       False    False          506813     NaN
# 3       4      False         1       False    False          506818     NaN
# 4       4      False         1       False    False          506823     NaN
# 5       4      False        68       False    False          506828     NaN
# 6       0      False         1       False    False          453638     NaN
# 7       5      False         1       False    False          517770     NaN
# 8       5      False         1       False    False          517790     NaN
# 9       3      False         1       False    False          517797     NaN
#
#                                           DetailsUrl  PointsDropped  \
# 0  http://cuetracker.net/Tournaments/china-champi...          False
# 1  http://cuetracker.net/Tournaments/riga-masters...          False
# 2  http://cuetracker.net/Tournaments/riga-masters...          False
# 3  http://cuetracker.net/Tournaments/riga-masters...          False
# 4  http://cuetracker.net/Tournaments/riga-masters...          False
# 5  http://cuetracker.net/Tournaments/riga-masters...          False
# 6  http://cuetracker.net/Tournaments/world-open/2...          False
# 7  http://cuetracker.net/Tournaments/china-champi...          False
# 8  http://cuetracker.net/Tournaments/china-champi...          False
# 9  http://cuetracker.net/Tournaments/china-champi...          False
#
#    ShowCommonNote  Estimated  Type  TableNo  \
# 0            True      False     1        0
# 1            True       True     1        0
# 2            True       True     1        0
# 3           False       True     1        0
# 4            True       True     1        0
# 5            True       True     1        0
# 6            True      False     1        0
# 7           False      False     1        0
# 8           False      False     1        0
# 9           False      False     1        0
#
#                                       VideoURL              InitDate  \
# 0  https://www.youtube.com/watch?v=jNtP5eMacos  2017-05-12T21:07:27Z
# 1                 https://youtu.be/8EK-3PydURY  2017-05-12T21:14:35Z
# 2  https://www.youtube.com/watch?v=3uRQRBKIAaQ  2017-05-12T21:16:41Z
# 3                                          NaN  2017-05-12T21:18:00Z
# 4  https://www.youtube.com/watch?v=bzPeIGRYroI  2017-05-12T21:18:27Z
# 5  https://www.youtube.com/watch?v=rGUyT6mgGxg  2017-05-12T21:18:54Z
# 6  https://www.youtube.com/watch?v=orJE8c4YqFs  2017-07-15T09:48:14Z
# 7                                          NaN  2017-05-12T21:27:18Z
# 8                                          NaN  2017-05-12T21:28:17Z
# 9                                          NaN  2017-05-12T21:28:57Z
#
#                 ModDate             StartDate               EndDate  \
# 0  2017-06-03T13:37:44Z  2017-06-03T13:37:44Z  2017-06-03T17:22:56Z
# 1  2017-06-23T16:08:16Z  2017-06-23T16:08:16Z  2017-06-23T18:10:23Z
# 2  2017-06-25T21:10:53Z  2017-06-24T13:02:31Z  2017-06-24T14:32:50Z
# 3  2017-06-24T16:24:22Z  2017-06-24T16:24:22Z  2017-06-24T17:52:23Z
# 4  2017-06-25T11:04:12Z  2017-06-25T11:04:12Z  2017-06-25T12:43:26Z
# 5  2017-06-25T12:54:21Z  2017-06-25T12:54:21Z  2017-06-25T15:43:41Z
# 6  2017-08-06T13:29:17Z  2017-08-06T13:29:17Z  2017-08-06T15:42:57Z
# 7  2017-08-17T11:34:16Z  2017-08-17T11:34:16Z  2017-08-17T14:02:40Z
# 8  2017-08-18T11:22:20Z  2017-08-18T11:22:20Z  2017-08-18T13:20:48Z
# 9  2017-08-19T06:01:36Z  2017-08-19T06:01:36Z  2017-08-19T08:36:59Z
#
#           ScheduledDate                                        FrameScores  \
# 0  2017-06-03T13:30:00Z                                                NaN
# 1  2017-06-23T16:00:00Z                                                NaN
# 2  2017-06-24T12:00:00Z                                                NaN
# 3  2017-06-24T16:00:00Z                                                NaN
# 4  2017-06-25T09:00:00Z                                                NaN
# 5  2017-06-25T12:00:00Z  86-36, 82-41 (70), 0-81 (56), 8-74<br/>5-77 (5...
# 6  2017-08-06T13:30:00Z                                                NaN
# 7  2017-08-17T11:30:00Z                                                NaN
# 8  2017-08-18T11:30:00Z                                                NaN
# 9  2017-08-19T06:00:00Z                                                NaN
#
#   Sessions Note ExtendedNote  WIN                           Name  \
# 0      NaN  NaN          NaN    1  China Championship Qualifiers
# 1      NaN  NaN          NaN    1                   Riga Masters
# 2      NaN  NaN          NaN    1                   Riga Masters
# 3      NaN  NaN          NaN    0                   Riga Masters
# 4      NaN  NaN          NaN    0                   Riga Masters
# 5      NaN  NaN          NaN    1                   Riga Masters
# 6      NaN  NaN          NaN    1          World Open Qualifiers
# 7      NaN  NaN          NaN    0             China Championship
# 8      NaN  NaN          NaN    0             China Championship
# 9      NaN  NaN          NaN    1             China Championship
#
#   StartDate_event EndDate_event     Sponsor  Season  Type_event  Num  \
# 0      2017-06-03    2017-06-06  EverGrande    2017  Qualifying    0
# 1      2017-06-23    2017-06-25   Kaspersky    2017     Ranking    0
# 2      2017-06-23    2017-06-25   Kaspersky    2017     Ranking    0
# 3      2017-06-23    2017-06-25   Kaspersky    2017     Ranking    0
# 4      2017-06-23    2017-06-25   Kaspersky    2017     Ranking    0
# 5      2017-06-23    2017-06-25   Kaspersky    2017     Ranking    0
# 6      2017-08-06    2017-08-09         NaN    2017  Qualifying    0
# 7      2017-08-16    2017-08-22  EverGrande    2017     Ranking    0
# 8      2017-08-16    2017-08-22  EverGrande    2017     Ranking    0
# 9      2017-08-16    2017-08-22  EverGrande    2017     Ranking    0
#
#                                           Venue       City  Country  \
# 0                                    Guild Hall    Preston  England
# 1                                    Arena Riga       Riga   Latvia
# 2                                    Arena Riga       Riga   Latvia
# 3                                    Arena Riga       Riga   Latvia
# 4                                    Arena Riga       Riga   Latvia
# 5                                    Arena Riga       Riga   Latvia
# 6                                    Guild Hall    Preston  England
# 7  Guangzhou Sports Institute Asian Games Venue  Guangzhou    China
# 8  Guangzhou Sports Institute Asian Games Venue  Guangzhou    China
# 9  Guangzhou Sports Institute Asian Games Venue  Guangzhou    China
#
#   Discipline  Main   Sex AgeGroup  Url Related Stage ValueType ShortName  \
# 0    snooker   623  Both        O  NaN     NaN     Q        CC       NaN
# 1    snooker   620  Both        O  NaN    riga     F        RM       NaN
# 2    snooker   620  Both        O  NaN    riga     F        RM       NaN
# 3    snooker   620  Both        O  NaN    riga     F        RM       NaN
# 4    snooker   620  Both        O  NaN    riga     F        RM       NaN
# 5    snooker   620  Both        O  NaN    riga     F        RM       NaN
# 6    snooker   638  Both        O  NaN     hwo     Q        WO       NaN
# 7    snooker   623  Both        O  NaN     NaN     F        CC       NaN
# 8    snooker   623  Both        O  NaN     NaN     F        CC       NaN
# 9    snooker   623  Both        O  NaN     NaN     F        CC       NaN
#
#    WorldSnookerId RankingType  EventPredictionID   Team  Format Twitter  \
# 0           13955          WR                  0  False       1     NaN
# 1           13953          WR               2701  False       1     NaN
# 2           13953          WR               2701  False       1     NaN
# 3           13953          WR               2701  False       1     NaN
# 4           13953          WR               2701  False       1     NaN
# 5           13953          WR               2701  False       1     NaN
# 6           13971          WR                  0  False       1     NaN
# 7           13955          WR               2702  False       1     NaN
# 8           13955          WR               2702  False       1     NaN
# 9           13955          WR               2702  False       1     NaN
#
#              HashTag  ConversionRate  AllRoundsAdded  PhotoURLs  \
# 0  ChinaChampionship             1.0            True        NaN
# 1        RigaMasters             1.0            True        NaN
# 2        RigaMasters             1.0            True        NaN
# 3        RigaMasters             1.0            True        NaN
# 4        RigaMasters             1.0            True        NaN
# 5        RigaMasters             1.0            True        NaN
# 6                NaN             1.0            True        NaN
# 7  ChinaChampionship             1.0            True        NaN
# 8  ChinaChampionship             1.0            True        NaN
# 9  ChinaChampionship             1.0            True        NaN
#
#    NumCompetitors  NumUpcoming  NumActive  NumResults Note_event  \
# 0               0            0          0          64        NaN
# 1             128            0          0          63        NaN
# 2             128            0          0          63        NaN
# 3             128            0          0          63        NaN
# 4             128            0          0          63        NaN
# 5             128            0          0          63        NaN
# 6               0            0          0          64        NaN
# 7             128            0          0          63        NaN
# 8             128            0          0          63        NaN
# 9             128            0          0          63        NaN
#
#                                           CommonNote  DefendingChampion  \
# 0  <a href="http://www.eurosportplayer.com/">Euro...                237
# 1  <a href="http://www.eurosportplayer.com/">Euro...                154
# 2  <a href="http://www.eurosportplayer.com/">Euro...                154
# 3  <a href="http://www.eurosportplayer.com/">Euro...                154
# 4  <a href="http://www.eurosportplayer.com/">Euro...                154
# 5  <a href="http://www.eurosportplayer.com/">Euro...                154
# 6  Watch on <a href="http://www.eurosportplayer.c...                  0
# 7  Watch on <a href="http://www.eurosportplayer.c...                237
# 8  Watch on <a href="http://www.eurosportplayer.c...                237
# 9  Watch on <a href="http://www.eurosportplayer.c...                237
#
#    PreviousEdition  Player1Seeding  Player2Seeding  Player1FirstSeasonAsPro  \
# 0              568             NaN             NaN                   1992.0
# 1              515             8.0            33.0                   1992.0
# 2              515             8.0            20.0                   1992.0
# 3              515            46.0             8.0                   2012.0
# 4              515            41.0             8.0                   2006.0
# 5              515            11.0             8.0                   1998.0
# 6                0             NaN             NaN                   1992.0
# 7              568            50.0            15.0                   2006.0
# 8              568            18.0            15.0                   1998.0
# 9              568            15.0            31.0                   1992.0
#
#    Player2FirstSeasonAsPro  Player1YearsAsPro  Player2YearsAsPro  LastSeason  \
# 0                   2010.0               25.0                7.0        2016
# 1                   1991.0               25.0               26.0        2016
# 2                   2011.0               25.0                6.0        2016
# 3                   1992.0                5.0               25.0        2016
# 4                   1992.0               11.0               25.0        2016
# 5                   1992.0               19.0               25.0        2016
# 6                   2016.0               25.0                1.0        2016
# 7                   1992.0               11.0               25.0        2016
# 8                   1992.0               19.0               25.0        2016
# 9                   2001.0               25.0               16.0        2016
#
#    Player1LastSeasonRank  Player1LastSeasonSum  Player2LastSeasonRank  \
# 0                   15.0              211975.0                   96.0
# 1                   15.0              211975.0                   40.0
# 2                   15.0              211975.0                   27.0
# 3                   53.0               74650.0                   15.0
# 4                   48.0               83662.0                   15.0
# 5                   18.0              197087.0                   15.0
# 6                   15.0              211975.0                  119.0
# 7                   50.0               77575.0                   15.0
# 8                   18.0              197087.0                   15.0
# 9                   15.0              211975.0                   31.0
#
#    Player2LastSeasonSum
# 0               18862.0
# 1               99387.0
# 2              132075.0
# 3              211975.0
# 4              211975.0
# 5              211975.0
# 6                5050.0
# 7              211975.0
# 8              211975.0
# 9              122500.0

# %%
matches.columns
# Out:
# Index(['ID', 'EventID', 'Round', 'Number', 'Player1ID', 'Score1', 'Walkover1',
#        'Player2ID', 'Score2', 'Walkover2', 'WinnerID', 'Unfinished', 'OnBreak',
#        'WorldSnookerID', 'LiveUrl', 'DetailsUrl', 'PointsDropped',
#        'ShowCommonNote', 'Estimated', 'Type', 'TableNo', 'VideoURL',
#        'InitDate', 'ModDate', 'StartDate', 'EndDate', 'ScheduledDate',
#        'FrameScores', 'Sessions', 'Note', 'ExtendedNote', 'WIN', 'Name',
#        'StartDate_event', 'EndDate_event', 'Sponsor', 'Season', 'Type_event',
#        'Num', 'Venue', 'City', 'Country', 'Discipline', 'Main', 'Sex',
#        'AgeGroup', 'Url', 'Related', 'Stage', 'ValueType', 'ShortName',
#        'WorldSnookerId', 'RankingType', 'EventPredictionID', 'Team', 'Format',
#        'Twitter', 'HashTag', 'ConversionRate', 'AllRoundsAdded', 'PhotoURLs',
#        'NumCompetitors', 'NumUpcoming', 'NumActive', 'NumResults',
#        'Note_event', 'CommonNote', 'DefendingChampion', 'PreviousEdition',
#        'Player1Seeding', 'Player2Seeding', 'Player1FirstSeasonAsPro',
#        'Player2FirstSeasonAsPro', 'Player1YearsAsPro', 'Player2YearsAsPro',
#        'LastSeason', 'Player1LastSeasonRank', 'Player1LastSeasonSum',
#        'Player2LastSeasonRank', 'Player2LastSeasonSum'],
#       dtype='object')

# %%
matches.to_csv('Raw_data.csv', index=False)

# %% [markdown]
# ### Exploratory data analysis

# %% [markdown]
# 1. Can we get Betfair historical data and compare how biased these "source of truth" probabilities are?
# 2. What are the most important features driving winning a match? Ranking difference, form, stage of competition etc etc
# 3. Systematic way of defining features?

# %% [markdown]
# ### Feature engineering
